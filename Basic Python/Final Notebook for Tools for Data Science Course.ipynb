# %% [markdown]
# # My jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Esteban López Mejía** <br>
# Current occupation: Web developer - Desired occupation: Data scientist

# %% [markdown]
# *I'm interested in data science because I'm a curious person, I've always love science and I want to generate an impact on society using data science.*

# %% [markdown]
# ### My code in cell #5 prints sums the numbers from 1 t 10 and shows the results

# %%
sum = 0
for i in range(11):
    sum += i
print(sum)
# Out:
# 55

# %% [markdown]
# <h1>HTML Cell</h1><br>
# <a href="https://developer.mozilla.org/es/docs/Web/HTML">More info about HTML</a>
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpngGRjYX1ca7qAADU3K6eGLj7ShQE3L2otdzfryl_Y9Ht2QRoQKYQbsXd36XIxMbYOw0&usqp=CAU" alt="Image not available">
# <h2>Basic you must learn for front end web development</h2>
# <ul>
#     <li>HTML</li>
#     <li>CSS</li>
#     <li>Javascript</li>
# </ul>
